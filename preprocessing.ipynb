# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
requirements_path = '/content/drive/MyDrive/requirements.txt'

with open(requirements_path, 'w') as file:
    file.write('librosa\nSpeechRecognition\njiwer\nmatplotlib\ngtts\ntorch\ntorchvision\ntorchaudio\nffmpeg\nopenai-whisper\ntensor\nnoisereduce\nscikit-learn\ntransformers\ndatasets\nevaluate')

# %%
# !pip install -r /content/drive/MyDrive/requirements.txt
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/requirements.txt (line 1)) (0.10.2.post1)
# Collecting SpeechRecognition (from -r /content/drive/MyDrive/requirements.txt (line 2))
#   Downloading SpeechRecognition-3.14.1-py3-none-any.whl.metadata (31 kB)
# Collecting jiwer (from -r /content/drive/MyDrive/requirements.txt (line 3))
#   Downloading jiwer-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/requirements.txt (line 4)) (3.10.0)
# Collecting gtts (from -r /content/drive/MyDrive/requirements.txt (line 5))
#   Downloading gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/requirements.txt (line 6)) (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/requirements.txt (line 7)) (0.20.1+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/requirements.txt (line 8)) (2.5.1+cu124)
# Collecting ffmpeg (from -r /content/drive/MyDrive/requirements.txt (line 9))
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting openai-whisper (from -r /content/drive/MyDrive/requirements.txt (line 10))
#   Downloading openai-whisper-20240930.tar.gz (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 14.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tensor (from -r /content/drive/MyDrive/requirements.txt (line 11))
#   Downloading tensor-0.3.6.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting noisereduce (from -r /content/drive/MyDrive/requirements.txt (line 12))
#   Downloading noisereduce-3.0.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/requirements.txt (line 13)) (1.6.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/requirements.txt (line 14)) (4.48.3)
# Collecting datasets (from -r /content/drive/MyDrive/requirements.txt (line 15))
#   Downloading datasets-3.3.0-py3-none-any.whl.metadata (19 kB)
# Collecting evaluate (from -r /content/drive/MyDrive/requirements.txt (line 16))
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (0.61.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from jiwer->-r /content/drive/MyDrive/requirements.txt (line 3)) (8.1.8)
# Collecting rapidfuzz>=3.9.7 (from jiwer->-r /content/drive/MyDrive/requirements.txt (line 3))
#   Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/requirements.txt (line 4)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/requirements.txt (line 4)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/requirements.txt (line 4)) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/requirements.txt (line 4)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from gtts->-r /content/drive/MyDrive/requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/drive/MyDrive/requirements.txt (line 6)) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/drive/MyDrive/requirements.txt (line 6)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/drive/MyDrive/requirements.txt (line 6)) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/drive/MyDrive/requirements.txt (line 6)) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->-r /content/drive/MyDrive/requirements.txt (line 6))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->-r /content/drive/MyDrive/requirements.txt (line 6))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->-r /content/drive/MyDrive/requirements.txt (line 6))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->-r /content/drive/MyDrive/requirements.txt (line 6))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->-r /content/drive/MyDrive/requirements.txt (line 6))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->-r /content/drive/MyDrive/requirements.txt (line 6))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->-r /content/drive/MyDrive/requirements.txt (line 6))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->-r /content/drive/MyDrive/requirements.txt (line 6))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->-r /content/drive/MyDrive/requirements.txt (line 6))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/drive/MyDrive/requirements.txt (line 6)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/drive/MyDrive/requirements.txt (line 6)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->-r /content/drive/MyDrive/requirements.txt (line 6))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/drive/MyDrive/requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/drive/MyDrive/requirements.txt (line 6)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r /content/drive/MyDrive/requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from openai-whisper->-r /content/drive/MyDrive/requirements.txt (line 10)) (4.67.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from openai-whisper->-r /content/drive/MyDrive/requirements.txt (line 10)) (10.6.0)
# Collecting tiktoken (from openai-whisper->-r /content/drive/MyDrive/requirements.txt (line 10))
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting Twisted (from tensor->-r /content/drive/MyDrive/requirements.txt (line 11))
#   Downloading twisted-24.11.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: PyYaml in /usr/local/lib/python3.11/dist-packages (from tensor->-r /content/drive/MyDrive/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from tensor->-r /content/drive/MyDrive/requirements.txt (line 11)) (4.25.6)
# Collecting construct (from tensor->-r /content/drive/MyDrive/requirements.txt (line 11))
#   Downloading construct-2.10.70-py3-none-any.whl.metadata (4.2 kB)
# Collecting pysnmp (from tensor->-r /content/drive/MyDrive/requirements.txt (line 11))
#   Downloading pysnmp-7.1.16-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r /content/drive/MyDrive/requirements.txt (line 13)) (3.5.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /content/drive/MyDrive/requirements.txt (line 14)) (0.28.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /content/drive/MyDrive/requirements.txt (line 14)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /content/drive/MyDrive/requirements.txt (line 14)) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /content/drive/MyDrive/requirements.txt (line 14)) (0.5.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->-r /content/drive/MyDrive/requirements.txt (line 15))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (2.2.2)
# Collecting xxhash (from datasets->-r /content/drive/MyDrive/requirements.txt (line 15))
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->-r /content/drive/MyDrive/requirements.txt (line 15))
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (3.11.12)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (1.18.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (4.3.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->-r /content/drive/MyDrive/requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts->-r /content/drive/MyDrive/requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts->-r /content/drive/MyDrive/requirements.txt (line 5)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts->-r /content/drive/MyDrive/requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts->-r /content/drive/MyDrive/requirements.txt (line 5)) (2025.1.31)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r /content/drive/MyDrive/requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->-r /content/drive/MyDrive/requirements.txt (line 15)) (2025.1)
# Requirement already satisfied: pyasn1!=0.5.0,>=0.4.8 in /usr/local/lib/python3.11/dist-packages (from pysnmp->tensor->-r /content/drive/MyDrive/requirements.txt (line 11)) (0.6.1)
# Collecting automat>=24.8.0 (from Twisted->tensor->-r /content/drive/MyDrive/requirements.txt (line 11))
#   Downloading Automat-24.8.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting constantly>=15.1 (from Twisted->tensor->-r /content/drive/MyDrive/requirements.txt (line 11))
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting hyperlink>=17.1.1 (from Twisted->tensor->-r /content/drive/MyDrive/requirements.txt (line 11))
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting incremental>=24.7.0 (from Twisted->tensor->-r /content/drive/MyDrive/requirements.txt (line 11))
#   Downloading incremental-24.7.2-py3-none-any.whl.metadata (8.1 kB)
# Collecting zope-interface>=5 (from Twisted->tensor->-r /content/drive/MyDrive/requirements.txt (line 11))
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->-r /content/drive/MyDrive/requirements.txt (line 1)) (2.22)
# Requirement already satisfied: setuptools>=61.0 in /usr/local/lib/python3.11/dist-packages (from incremental>=24.7.0->Twisted->tensor->-r /content/drive/MyDrive/requirements.txt (line 11)) (75.1.0)
# Downloading SpeechRecognition-3.14.1-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 66.4 MB/s eta 0:00:00
# Downloading jiwer-3.1.0-py3-none-any.whl (22 kB)
# Downloading gTTS-2.5.4-py3-none-any.whl (29 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.0 MB/s eta 0:00:00
# Downloading noisereduce-3.0.3-py3-none-any.whl (22 kB)
# Downloading datasets-3.3.0-py3-none-any.whl (484 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 42.1 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 10.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 16.6 MB/s eta 0:00:00
# Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 105.8 MB/s eta 0:00:00
# Downloading construct-2.10.70-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 7.1 MB/s eta 0:00:00
# Downloading pysnmp-7.1.16-py3-none-any.whl (340 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.0/341.0 kB 34.8 MB/s eta 0:00:00
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 73.2 MB/s eta 0:00:00
# Downloading twisted-24.11.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 96.2 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 23.0 MB/s eta 0:00:00
# Downloading Automat-24.8.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.8 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 8.3 MB/s eta 0:00:00
# Downloading incremental-24.7.2-py3-none-any.whl (20 kB)
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 28.5 MB/s eta 0:00:00
# Building wheels for collected packages: ffmpeg, openai-whisper, tensor
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=efa4ad61b2bf840678f782e90c8bc07a4149a9e1b5e00903d4a067095671d2c3
#   Stored in directory: /root/.cache/pip/wheels/56/30/c5/576bdd729f3bc062d62a551be7fefd6ed2f761901568171e4e
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20240930-py3-none-any.whl size=803373 sha256=97e59ead755474134aab50a7407beb1767e1bfab3ca93a6f573931fc840c254e
#   Stored in directory: /root/.cache/pip/wheels/2f/f2/ce/6eb23db4091d026238ce76703bd66da60b969d70bcc81d5d3a
#   Building wheel for tensor (setup.py) ... done
#   Created wheel for tensor: filename=tensor-0.3.6-py3-none-any.whl size=71551 sha256=75e9109ef645e5fe1523935f186561ff035afbe437d07f1d2a64580f4de4b5a3
#   Stored in directory: /root/.cache/pip/wheels/d9/71/a7/060c2d3ffc42a12287181a642b48a18699f76199693f835719
# Successfully built ffmpeg openai-whisper tensor
# Installing collected packages: ffmpeg, zope-interface, xxhash, SpeechRecognition, rapidfuzz, pysnmp, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, incremental, hyperlink, dill, construct, constantly, automat, Twisted, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, jiwer, gtts, tensor, nvidia-cusolver-cu12, noisereduce, datasets, openai-whisper, evaluate
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed SpeechRecognition-3.14.1 Twisted-24.11.0 automat-24.8.1 constantly-23.10.4 construct-2.10.70 datasets-3.3.0 dill-0.3.8 evaluate-0.4.3 ffmpeg-1.4 gtts-2.5.4 hyperlink-21.0.0 incremental-24.7.2 jiwer-3.1.0 multiprocess-0.70.16 noisereduce-3.0.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 openai-whisper-20240930 pysnmp-7.1.16 rapidfuzz-3.12.1 tensor-0.3.6 tiktoken-0.9.0 xxhash-3.5.0 zope-interface-7.2

# %%
import os
import librosa
import numpy as np
import noisereduce as nr
import pandas as pd
from sklearn.model_selection import train_test_split
import soundfile as sf
from datasets import Dataset
import evaluate
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

# %%
SAMPLE_RATE = 16000
IMAGE_DIR = "/content/drive/MyDrive/captchaDatabase/captchas/images"
AUDIO_DIR = "/content/drive/MyDrive/captchaDatabase/captchas/audio"
CSV_PATH = "/content/drive/MyDrive/captch_dataset/extracted_image_captcha_data.csv"

# %%
df = pd.read_csv(CSV_PATH)

# %%
df.head(5)
# Out:
#          image_file image_text
# 0  captcha_9023.png     SfPEys
# 1  captcha_9024.png     mTiB49
# 2  captcha_9025.png     cFSrnk
# 3  captcha_9026.png     t52ejf
# 4  captcha_9027.png     X4AJ70

# %%
audio_files = sorted([f for f in os.listdir(AUDIO_DIR) if f.endswith('.wav')])
assert len(df) == len(audio_files),
df['audio_file'] = [os.path.join(AUDIO_DIR, f) for f in audio_files]

# %%
train_df, test_df = train_test_split(df, train_size=0.8, random_state=42, shuffle=False)

# %%
import torchaudio
from joblib import Parallel, delayed

SAMPLE_RATE = 16000

def preprocess_audio(audio_file, apply_augmentation=True):

    waveform, sample_rate = torchaudio.load(audio_file)

    if sample_rate != SAMPLE_RATE:
        waveform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=SAMPLE_RATE)(waveform)

    waveform = waveform.numpy().flatten()

    noise_estimate = waveform[:int(0.5 * SAMPLE_RATE)]
    waveform = nr.reduce_noise(y=waveform, sr=SAMPLE_RATE, y_noise=noise_estimate)
    waveform, _ = librosa.effects.trim(waveform, top_db=min(30, np.max(waveform) * 100))
    waveform = waveform / (np.max(np.abs(waveform)) + 1e-7)

    if apply_augmentation:
        aug_type = np.random.choice(['noise', 'stretch', 'pitch'])
        if aug_type == 'noise':
            waveform += np.random.normal(0, 0.005, waveform.shape)
        elif aug_type == 'stretch':
            waveform = librosa.effects.time_stretch(waveform.astype(np.float32), rate=np.random.uniform(0.9, 1.1))
        elif aug_type == 'pitch':
            waveform = librosa.effects.pitch_shift(waveform.astype(np.float32), sr=SAMPLE_RATE, n_steps=np.random.randint(-2, 2))

    return waveform

# %%
train_waveforms = Parallel(n_jobs=-1)(delayed(preprocess_audio)(audio, True) for audio in train_df['audio_file'])
test_waveforms = Parallel(n_jobs=-1)(delayed(preprocess_audio)(audio, False) for audio in test_df['audio_file'])

# %%
import numpy as np

np.save("/content/drive/MyDrive/captch_dataset/train_waveforms.npy", np.array(train_waveforms, dtype=object))
np.save("/content/drive/MyDrive/captch_dataset/test_waveforms.npy", np.array(test_waveforms, dtype=object))
